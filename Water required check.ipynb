# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_excel("parmeters.xlsx")
data
# Out:
#          T   M   H
# 0       30  71  98
# 1       33  72  98
# 2       30  71  98
# 3       30  71  99
# 4       30  75  98
# ...     ..  ..  ..
# 106742  24  17   8
# 106743  24  17  12
# 106744  24  17  12
# 106745  24  17  14
# 106746  24  17  14
#
# [106747 rows x 3 columns]

# %%
data["water required"] = 1

# %% [markdown]
# fenugreek : temp 25-30
#     moisture : >40
#         humidity<35
#
#         no water

# %%
data["water required"] = data["M"].apply(lambda x: True if x<50 else False) & data["H"].apply(lambda x: True if x<=30 else False) & data["T"].apply(lambda x: True if (x>=20) else False)

# %%
data[data["water required"]==True]
# Out:
#          T   M   H  water required
# 75370   29  49  18            True
# 75490   29  49   4            True
# 75491   29  49  11            True
# 75492   29  48   4            True
# 75493   29  48   7            True
# ...     ..  ..  ..             ...
# 106742  24  17   8            True
# 106743  24  17  12            True
# 106744  24  17  12            True
# 106745  24  17  14            True
# 106746  24  17  14            True
#
# [28738 rows x 4 columns]

# %%
data.to_excel("Water requirement check.xlsx")

# %%
for i in data.iterrows():
    print(i[1]['water required'])
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# ...

# %%
data[data["water required"]==True]
# Out:
# Empty DataFrame
# Columns: [T, M, H, water required]
# Index: []
