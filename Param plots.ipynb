# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("parmeters.xlsx")

# %%
data[data["H"]<=10]
# Out:
#          T   M   H
# 414     30  75   4
# 415     30  77   4
# 417     31  73   4
# 420     32  76   4
# 71429   28  81  10
# ...     ..  ..  ..
# 106722  24  16   7
# 106731  23  17   8
# 106733  24  17   5
# 106741  24  17   6
# 106742  24  17   8
#
# [4089 rows x 3 columns]

# %%
plt.rcParams["figure.figsize"]=(16,9)
plt.plot(data["T"].head(5000))

# %%
plt.rcParams["figure.figsize"]=(16,9)
plt.plot(data["H"])

# %%
plt.rcParams["figure.figsize"]=(16,9)
plt.plot(data["M"])
